# %% [markdown]
# what is monotonic stack 单调栈
#
# bottom -> top
# 小 -》 大
# 【1 ，3，5，8】
#
#
# 当你要 push 一个新元素 x 时：
# 如果 x >= 栈顶 → 直接入栈
# 如果 x < 栈顶  → 一直 pop，直到满足递增
#
# 例子
# push 2 到【1 ，3，5，8】   -》 【1，2】

# %% [markdown]
# ### 739 Daily Temperature  用单调栈
#
# 思路 单调栈存 那些还没找到比自己大的数字 【所以栈头到尾巴是递增】
#
# 当前遍历的元素T[i]
#   1. 小于栈顶元素T[st.top()]的情况
#     push to stack
#
# 2， 等于栈顶元素T[st.top()]的情况
#     push to stack
# 3.大于栈顶元素T[st.top()]的情况
#
#     while  each elem from stack:
#         updatae output [stack.top]
#         pop stack top
#     push to stack

# %% [markdown]
# moni circular array looping
#
# for i in range(2*n):
#     idx = i % n

# %% [markdown]
# lc84
#  # let array [ 5,6,7,6]
#   # stack keep increasing order 5,6,7 ;if it meet 567,1, it should pop all
#         # if cur < stack top, pop all and calcualte area
#
# in the while loop, when pop elem =5, cnt = 4
